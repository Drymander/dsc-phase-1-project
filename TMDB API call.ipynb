# %%
pip install tmdbsimple
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
### code taken from https://dev.to/m0nica/how-to-use-the-tmdb-api-to-find-films-with-the-highest-revenue-82p

import requests # to make TMDB API calls
import locale # to format currency as USD
locale.setlocale( locale.LC_ALL, '' )

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter # to format currency on charts axis

api_key = '64bc8db1ac9143a7dbb820d7d420ac96'

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' +  api_key + '&page=1&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/f5F4cRhQdUbyVbB5lTNCwUzD6BP.jpg',
#    'genre_ids': [80, 53, 18],
#    'id': 475557,
#    'original_language': 'en',
#    'original_title': 'Joker',
#    'overview': 'During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.',
#    'popularity': 397.257,
#    'poster_path': '/udDclJoHjfjb8Ekgsd4FDteOkCU.jpg',
#    'release_date': '2019-10-02',
#    'title': 'Joker',
#    'video': False,
#    'vote_average': 8.2,
#    'vote_count': 16993},
#   {'adult': False,
#    'backdrop_path': '/uovH5k4BAEPqXqxgwVrTtqH169g.jpg',
#    'genre_ids': [878, 28],
#    'id': 373571,
#    'original_language': 'en',
#    'original_title': 'Godzilla: King of the Monsters',
# ...

# %%
import tmdbsimple as tmdb
tmdb.API_KEY = '64bc8db1ac9143a7dbb820d7d420ac96'

# %%
movie = tmdb.Movies(603)

# %%
movie

# %%
movie.info()
# Out:
# {'adult': False,
#  'backdrop_path': '/fNG7i7RqMErkcqhohV2a6cV1Ehy.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/lh4aGpd3U9rm9B8Oqr6CUgQLtZL.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 49.266,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
# ...

# %%
movie.budget
# Out:
# 63000000

# %%
movie.revenue
# Out:
# 463517383

# %%
page_number = 1

response1 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
                         +  api_key + '&page=' + '1' + 
                         '&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

response2 = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
                         +  api_key + '&page=' + '2' + 
                         '&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

# %%
res1 = response1.json()
res2 = response2.json()

# %%
import pandas as pd


df = pd.DataFrame(res2['results'])

df
# Out:
#     adult                     backdrop_path                       genre_ids  \
# 0   False  /e7tMI0zVKJB2TS74TaBifIZIkCp.jpg                    [27, 28, 35]
# 1   False  /kNGW6f47HUk0hISjj1AvXoLNL3L.jpg             [28, 878, 27, 9648]
# 2   False  /tXQP5bdZbNWogkQhTHy0H5kqlUy.jpg                            [53]
# 3   False  /a0xTB1vBxMGt6LGG4N7k1wO9lfL.jpg                    [28, 12, 35]
# 4   False  /lm4xH0YwFbVvTgdtau1thNK5S6J.jpg                    [53, 27, 18]
# 5   False  /xJWPZIYOEFIjZpBL7SVBGnzRYXp.jpg  [10751, 16, 12, 35, 14, 10402]
# 6   False  /A3DD0R6vZ5SwD0qGKaU7HL5KVat.jpg                            [28]
# 7   False  /ifBIpsuutQlul3Mexjw2QdkFXG4.jpg                        [28, 53]
# 8   False  /k2WyDw2NTUIWnuEs5gT7wgrCQg6.jpg                        [28, 53]
# 9   False  /n3UanIvmnBlH531pykuzNs4LbH6.jpg                    [18, 28, 36]
# 10  False  /nN4Gs3vZAOJ1D6FRtrwbU9VGYwU.jpg              [16, 10749, 10751]
# ...

# %%
res1['results'].extend(res2['results'])

# %%
res1
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/f5F4cRhQdUbyVbB5lTNCwUzD6BP.jpg',
#    'genre_ids': [80, 53, 18],
#    'id': 475557,
#    'original_language': 'en',
#    'original_title': 'Joker',
#    'overview': 'During the 1980s, a failed stand-up comedian is driven insane and turns to a life of crime and chaos in Gotham City while becoming an infamous psychopathic crime figure.',
#    'popularity': 397.257,
#    'poster_path': '/udDclJoHjfjb8Ekgsd4FDteOkCU.jpg',
#    'release_date': '2019-10-02',
#    'title': 'Joker',
#    'video': False,
#    'vote_average': 8.2,
#    'vote_count': 16993},
#   {'adult': False,
#    'backdrop_path': '/uovH5k4BAEPqXqxgwVrTtqH169g.jpg',
#    'genre_ids': [878, 28],
#    'id': 373571,
#    'original_language': 'en',
#    'original_title': 'Godzilla: King of the Monsters',
# ...

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
                         +  api_key + '&page=' + str(page_number) + 
                         '&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

# while page_number
#     response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
#                          +  api_key + '&page=' + page_number + 
#                          '&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

# %%
response
# Out:
# <Response [200]>

# %%
# with open('final_results.json',"w") as file:
#     file.write("")

# final_results.json()

# %%
# year = 2015

#     page_number = 1

#     response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
#                              +  api_key + '&page=' + str(page_number) + 
#                              '&with_original_language=en&primary_release_year=' + str(year) + '&with_release_type=3&with_runtime.gte=80')

#     total_pages = response.json()['total_pages']
#     # total_pages = 5

#     results = response.json()['results']

#     while page_number < total_pages:

#         page_number += 1

#         response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
#                              +  api_key + '&page=' + str(page_number) + 
#                              '&with_original_language=en&primary_release_year=' + str(year) + '&with_release_type=3&with_runtime.gte=80')

#         results.extend(response.json()['results'])

#     final_results.extend(results)

#     results

# %%
results = []
    
for year in [2012, 2013, 2014]:

    page_number = 1

    response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
                             +  api_key + '&page=' + str(page_number) + 
                             '&with_original_language=en&primary_release_year=' + str(year) + '&with_release_type=3&with_runtime.gte=80')

    total_pages = response.json()['total_pages']
    # total_pages = 5

    results.extend(response.json()['results'])

    while page_number < total_pages:

        page_number += 1

        response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
                             +  api_key + '&page=' + str(page_number) + 
                             '&with_original_language=en&primary_release_year=' + str(year) + '&with_release_type=3&with_runtime.gte=80')

        results.extend(response.json()['results'])

#     final_results.extend(results)

# %%
df = pd.DataFrame(results)

# %%
df.to_csv('2012-2014.csv')

# %%
# response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key=' 
#                          +  api_key + '&page=' + str(page_number) + 
#                          '&with_original_language=en&primary_release_year=2019&with_release_type=3&with_runtime.gte=80')

# %%
# df = pd.DataFrame(response.json()['total_pages'])

# %%
df = df.loc[df.id != 293471]

# %%
movie = tmdb.Movies(99861)
movie.releases()
for c in movie.countries:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])

# %%
movie.info()

# %%
df_sample = df.head(20)

# %%
df_sample

# %%
# df_sample_ids = df_sample['id']

df = pd.read_csv('2015-2019.csv')

df_ids = df['id']

full_movies = []

df_sample_ids = df_sample['id']
for idx in df_sample_ids:

# df_ids = df['id']
# for idx in df_ids:
    
    movie = tmdb.Movies(idx)
    
    movie_dic = {}
    
    movie_dic.update(movie.info())
    
    movie.releases()
    for c in movie.countries:
        if c['iso_3166_1'] == 'US':
            certification = c['certification']
        else:
            certification = 'None'
    
    movie_dic.update({'mpaa_rating' : certification})
    
    full_movies.append(movie_dic)

df_full = pd.DataFrame(full_movies)

df_full.to_csv('2015-2019 FULL.csv')

# %%
# my_dic = {'mpaa' : }

# my_dic.update(movie.info())

# my_dic.update({'mpaa_rating': 'R'})

# %%
df_sample_ids = pd.DataFrame(full_movies)
df_sample_ids

# %%
df = pd.read_csv('2015-2019.csv')

# %%
df_sample = df.head()

# %%
df_sample

# %%
# df_sample_ids = df_sample['id']

df_ids = df['id']

full_movies = []

for idx in df_ids:
    movie = tmdb.Movies(idx)
    
    movie_dic = {}
    
    movie_dic.update(movie.info())
    
    movie.releases()
    for c in movie.countries:
        if c['iso_3166_1'] == 'US':
            certification = c['certification']
#         else:
#             certification = 'None'
    
    movie_dic.update({'mpaa_rating' : str(certification)})
    
    full_movies.append(movie_dic)

df_full = pd.DataFrame(full_movies)

df_full.to_csv('2012-2014 FULL.csv')

# %%
df_sample_run

df_sample_run.to_csv('2015-2019 FULL.csv')

# %%
df_full
